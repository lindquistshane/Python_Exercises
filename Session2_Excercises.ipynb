# %% [markdown]
# Exercise-1
# ----------
# * Shane Lindquist
# * <span style="background-color: crimson
#       ">sjl241@scarletmail.rutgers.edu</span>

# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/lindq/OneDrive/Desktop/MSBA degree/Big Data Analysis/soybean.csv", na_values = '?')
df.describe()
# Out:
#              date  plant-stand      precip        temp        hail  \
# count  307.000000   300.000000  296.000000  301.000000  266.000000
# mean     3.521173     0.466667    1.577703    1.126246    0.206767
# std      1.715569     0.499721    0.713580    0.625040    0.405750
# min      0.000000     0.000000    0.000000    0.000000    0.000000
# 25%      2.000000     0.000000    1.000000    1.000000    0.000000
# 50%      4.000000     0.000000    2.000000    1.000000    0.000000
# 75%      5.000000     1.000000    2.000000    2.000000    0.000000
# max      6.000000     1.000000    2.000000    2.000000    1.000000
#
#         crop-hist  area-damaged    severity    seed-tmt  germination  ...  \
# count  307.000000    307.000000  266.000000  266.000000   271.000000  ...
# mean     1.814332      1.638436    0.778195    0.548872     1.014760  ...
# std      0.994128      1.079921    0.620145    0.632052     0.798009  ...
# ...

# %%
df.head()
# Out:
#                    class date plant-stand precip temp hail crop-hist  \
# 0  diaporthe-stem-canker    6           0      2    1    0         1
# 1  diaporthe-stem-canker    4           0      2    1    0         2
# 2  diaporthe-stem-canker    3           0      2    1    0         1
# 3  diaporthe-stem-canker    3           0      2    1    0         1
# 4  diaporthe-stem-canker    6           0      2    1    0         2
#
#   area-damaged severity seed-tmt  ... int-discolor sclerotia fruit-pods  \
# 0            1        1        0  ...            0         0          0
# 1            0        2        1  ...            0         0          0
# 2            0        2        1  ...            0         0          0
# 3            0        2        0  ...            0         0          0
# 4            0        1        0  ...            0         0          0
#
#   fruit spots seed mold-growth seed-discolor seed-size hriveling roots
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 36 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   class            309 non-null    object
#  1   date             309 non-null    object
#  2   plant-stand      309 non-null    object
#  3   precip           309 non-null    object
#  4   temp             309 non-null    object
#  5   hail             309 non-null    object
#  6   crop-hist        309 non-null    object
#  7   area-damaged     309 non-null    object
#  8   severity         309 non-null    object
#  9   seed-tmt         309 non-null    object
#  10  germination      309 non-null    object
#  11  plant-growth     309 non-null    object
#  12  leaves           309 non-null    object
#  13  leafspots-halo   309 non-null    object
#  14  leafspots-marg   309 non-null    object
#  15  leafspot-size    309 non-null    object
# ...

# %%
df.shape
# Out:
# (309, 36)

# %% [markdown]
# Exercise-2
# ----------

# %%
#list all the columns in the soybean dataframe
list(df)
# Out:
# ['class',
#  'date',
#  'plant-stand',
#  'precip',
#  'temp',
#  'hail',
#  'crop-hist',
#  'area-damaged',
#  'severity',
#  'seed-tmt',
#  'germination',
#  'plant-growth',
#  'leaves',
#  'leafspots-halo',
#  'leafspots-marg',
#  'leafspot-size',
#  'leaf-shread',
#  'leaf-malf',
#  'leaf-mild',
#  'stem',
#  'lodging',
#  'stem-cankers',
#  'canker-lesion',
#  'fruiting-bodies',
#  'external decay',
#  'mycelium',
#  'int-discolor',
#  'sclerotia',
#  'fruit-pods',
#  'fruit spots',
#  'seed',
#  'mold-growth',
#  'seed-discolor',
#  'seed-size',
#  'hriveling',
#  'roots']

# %%
#try different ways of displaying rows 23-36 and columns 6-12
df.iloc[23:37, [5,6,7,8,9,10,11]]
# Out:
#    hail crop-hist area-damaged severity seed-tmt germination plant-growth
# 23    0         0            1        1        1           2            1
# 24    0         1            1        2        1           2            1
# 25    0         3            1        2        0           2            1
# 26    0         0            1        1        0           1            1
# 27    0         2            1        1        0           1            1
# 28    0         1            1        2        0           2            1
# 29    ?         ?            ?        ?        ?           ?            ?
# 30    0         1            1        2        0           2            1
# 31    1         1            1        1        0           0            1
# 32    ?         3            1        ?        ?           ?            1
# 33    ?         2            1        ?        ?           ?            1
# 34    0         2            1        2        1           1            1
# ...

# %%
df.loc[23:37,['hail','crop-hist','area-damaged','severity','seed-tmt','germination','plant-growth']]
# Out:
#    hail crop-hist area-damaged severity seed-tmt germination plant-growth
# 23    0         0            1        1        1           2            1
# 24    0         1            1        2        1           2            1
# 25    0         3            1        2        0           2            1
# 26    0         0            1        1        0           1            1
# 27    0         2            1        1        0           1            1
# 28    0         1            1        2        0           2            1
# 29    ?         ?            ?        ?        ?           ?            ?
# 30    0         1            1        2        0           2            1
# 31    1         1            1        1        0           0            1
# 32    ?         3            1        ?        ?           ?            1
# 33    ?         2            1        ?        ?           ?            1
# 34    0         2            1        2        1           1            1
# ...

# %%
#Display records where temp is 1.0, severity is 2.0, and fruitspots is either 4.0 or 0
df.loc[(df.temp == '1') & (df.severity == '2') & (df["fruit spots"] == '0') | (df["fruit spots"] == '4')]
# Out:
#                      class date plant-stand precip temp hail crop-hist  \
# 0    diaporthe-stem-canker    6           0      2    1    0         1
# 1    diaporthe-stem-canker    4           0      2    1    0         2
# 2    diaporthe-stem-canker    3           0      2    1    0         1
# 3    diaporthe-stem-canker    3           0      2    1    0         1
# 4    diaporthe-stem-canker    6           0      2    1    0         2
# 5    diaporthe-stem-canker    5           0      2    1    0         3
# 6    diaporthe-stem-canker    5           0      2    1    0         2
# 7    diaporthe-stem-canker    4           0      2    1    1         1
# 8    diaporthe-stem-canker    6           0      2    1    0         3
# 9    diaporthe-stem-canker    4           0      2    1    0         2
# 10            charcoal-rot    6           0      0    2    0         1
# 11            charcoal-rot    4           0      0    1    1         1
# ...

# %% [markdown]
# Exercise-3
# ----------

# %%
#insert a new column which contains the sum of the values in the other 'leaf' columns
cols = [
    "leafspots-halo",
    "leafspots-marg",
    "leafspot-size",
    "leaf-shread",
    "leaf-malf",
    "leaf-mild"
]

#the values need to be cast as numbers in order to sum, as we saw in the prior step they are currently 'objects'
df['leaf_disease'] = df[cols].apply(pd.to_numeric, errors="coerce").sum(axis=1)
df['leaf_disease'].head()
# Out:
# 0    4.0
# 1    4.0
# 2    4.0
# 3    4.0
# 4    4.0
# Name: leaf_disease, dtype: float64

# %%
#insert a new column called 'leaf_category' use it to categorize the values in leaf_disease to low:<2, medium:3-5, or high:>5
leaf_disease = df['leaf_disease']
bins = [0,2,5,100]
bin_names = ['low', 'medium', 'high']
df['leaf_category'] = pd.cut(leaf_disease,bins,labels=bin_names)

# %%
#Store the new dataframe as a .csv file in the present working directory
df.to_csv('soybean2.csv', index=False)

# %%
#Delete the two new columns we just created
df.drop(columns = ['leaf_disease', 'leaf_category'], inplace = True)

# %%
df.head()
# Out:
#                    class date plant-stand precip temp hail crop-hist  \
# 0  diaporthe-stem-canker    6           0      2    1    0         1
# 1  diaporthe-stem-canker    4           0      2    1    0         2
# 2  diaporthe-stem-canker    3           0      2    1    0         1
# 3  diaporthe-stem-canker    3           0      2    1    0         1
# 4  diaporthe-stem-canker    6           0      2    1    0         2
#
#   area-damaged severity seed-tmt  ... int-discolor sclerotia fruit-pods  \
# 0            1        1        0  ...            0         0          0
# 1            0        2        1  ...            0         0          0
# 2            0        2        1  ...            0         0          0
# 3            0        2        0  ...            0         0          0
# 4            0        1        0  ...            0         0          0
#
#   fruit spots seed mold-growth seed-discolor seed-size hriveling roots
# ...

# %% [markdown]
# Exercise-4
# ----------

# %%
#Insert a new column called "disease_average" in the soybean dataframe. The new column is the average of the values of the columns starting with "area-damaged" until the column (inclusive of) "sclerotia"
cols2 = [
    'area-damaged',
    'severity',
    'seed-tmt',
    'germination',
    'plant-growth',
    'leaves',
    'leafspots-halo',
    'leafspots-marg',
    'leafspot-size',
    'leaf-shread',
    'leaf-malf',
    'leaf-mild',
    'stem',
    'lodging',
    'stem-cankers',
    'canker-lesion',
    'fruiting-bodies',
    'external decay',
    'mycelium',
    'int-discolor',
    'sclerotia'
]

#the values need to be cast as numbers in order to sum, as we saw in the prior step they are currently 'objects'
df['disease_average'] = df[cols2].apply(pd.to_numeric, errors="coerce").mean(axis=1)
df['disease_average'].head()
# Out:
# 0    0.761905
# 1    0.809524
# 2    0.809524
# 3    0.714286
# 4    0.761905
# Name: disease_average, dtype: float64

# %%
#Sort the dataframe in descending order of the values in the new column you created ("disease_average")
df2 = df.sort_values(by="disease_average")
df2
# Out:
#                       class date plant-stand precip temp hail crop-hist  \
# 153        bacterial-blight    2           0      1    1    0         0
# 163       bacterial-pustule    2           0      1    0    0         0
# 203  phyllosticta-leaf-spot    3           1      1    1    0         0
# 204  phyllosticta-leaf-spot    3           0      0    1    1         2
# 159        bacterial-blight    2           0      1    1    0         3
# ..                      ...  ...         ...    ...  ...  ...       ...
# 303            2-4-d-injury    ?           ?      ?    ?    ?         ?
# 307        herbicide-injury    1           1      ?    0    ?         1
# 305        herbicide-injury    0           1      ?    0    ?         0
# 308        herbicide-injury    1           1      ?    0    ?         1
# 29                        ?    ?           ?      ?    ?    ?         ?
#
#     area-damaged severity seed-tmt  ... sclerotia fruit-pods fruit spots seed  \
# ...

# %% [markdown]
# Exercise-5
# ----------

# %%
#insert a new column called "disease_category", the new column should have the categories low, medium, and high depending on the value of the disease_average column (<0.5, 0.5 - 1, >1)
disease_average = df['disease_average']
bins = [0,.5,1,100]
bin_names = ['low', 'medium', 'high']
df['disease_category'] = pd.cut(disease_average,bins,labels=bin_names)
df.loc[:,['disease_category','disease_average']]
# Out:
#     disease_category  disease_average
# 0             medium         0.761905
# 1             medium         0.809524
# 2             medium         0.809524
# 3             medium         0.714286
# 4             medium         0.761905
# ..               ...              ...
# 304           medium         0.888889
# 305             high         1.222222
# 306           medium         0.888889
# 307             high         1.222222
# 308             high         1.222222
#
# [309 rows x 2 columns]

# %%
#count the number of records per the "disease_category" column
print(pd.Series(df['disease_category']).value_counts())
# Out:
# disease_category
# medium    183
# low       121
# high        4
# Name: count, dtype: int64

# %%
#how many records in each of the disease categories are treated for seed disease (seed-tmt will be 1)
df.loc[df["seed-tmt"] == "1", "disease_category"].value_counts()
# Out:
# disease_category
# medium    66
# low       40
# high       0
# Name: count, dtype: int64

# %%
#Create a pivot table to display the average value of "area-damaged" for each of the disease categories and seed treatment status ("seed-tmt")
import numpy as np
df["area-damaged"] = pd.to_numeric(df["area-damaged"], errors="coerce")
pivotdf = pd.pivot_table(df, values = 'area-damaged',
                         index=['disease_category'], columns=['seed-tmt'], aggfunc= np.mean)
pivotdf
# Out:
# C:\Users\lindq\AppData\Local\Temp\ipykernel_19352\2377156965.py:4: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivotdf = pd.pivot_table(df, values = 'area-damaged',
# C:\Users\lindq\AppData\Local\Temp\ipykernel_19352\2377156965.py:4: FutureWarning: The provided callable <function mean at 0x0000017B9E3E5800> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivotdf = pd.pivot_table(df, values = 'area-damaged',
# seed-tmt                 0         1         2    ?
# disease_category
# low               1.462687  1.575000  1.250000  2.5
# medium            1.534247  1.969697  2.833333  1.0
# high                   NaN       NaN       NaN  3.0

# %% [markdown]
# Markdown-6
# ----------

# %%
#Explore the presence of missing values and duplicates in the dataset.
df[df.severity.isnull()]
# Out:
#                            class  date  plant-stand  precip  temp  hail  \
# 29                           NaN   NaN          NaN     NaN   NaN   NaN
# 32              phytophthora-rot   1.0          1.0     2.0   1.0   NaN
# 33              phytophthora-rot   2.0          1.0     2.0   2.0   NaN
# 35              phytophthora-rot   2.0          1.0     2.0   2.0   NaN
# 36              phytophthora-rot   3.0          1.0     2.0   1.0   NaN
# 39              phytophthora-rot   2.0          1.0     1.0   1.0   NaN
# 41              phytophthora-rot   2.0          1.0     2.0   1.0   NaN
# 42              phytophthora-rot   1.0          1.0     2.0   1.0   NaN
# 46              phytophthora-rot   2.0          1.0     2.0   2.0   NaN
# 48              phytophthora-rot   2.0          1.0     1.0   2.0   NaN
# 52              phytophthora-rot   1.0          1.0     2.0   1.0   NaN
# 53              phytophthora-rot   3.0          1.0     2.0   1.0   NaN
# ...

# %%
#Replace the missing values in each of columns of the adult dataframe with respective median values
df_filled = df.fillna(df.mean(numeric_only=True))
df_filled
# Out:
#                      class  date  plant-stand    precip  temp      hail  \
# 0    diaporthe-stem-canker   6.0          0.0  2.000000   1.0  0.000000
# 1    diaporthe-stem-canker   4.0          0.0  2.000000   1.0  0.000000
# 2    diaporthe-stem-canker   3.0          0.0  2.000000   1.0  0.000000
# 3    diaporthe-stem-canker   3.0          0.0  2.000000   1.0  0.000000
# 4    diaporthe-stem-canker   6.0          0.0  2.000000   1.0  0.000000
# ..                     ...   ...          ...       ...   ...       ...
# 304       herbicide-injury   1.0          1.0  1.577703   0.0  0.206767
# 305       herbicide-injury   0.0          1.0  1.577703   0.0  0.206767
# 306       herbicide-injury   1.0          1.0  1.577703   0.0  0.206767
# 307       herbicide-injury   1.0          1.0  1.577703   0.0  0.206767
# 308       herbicide-injury   1.0          1.0  1.577703   0.0  0.206767
#
#      crop-hist  area-damaged  severity  seed-tmt  ...  int-discolor  \
# ...
